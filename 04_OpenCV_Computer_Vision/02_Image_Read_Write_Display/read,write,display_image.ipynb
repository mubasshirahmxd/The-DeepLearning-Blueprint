# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

# %%
input = cv2.imread(r"C:\Users\MUBASSHIR\OneDrive\Desktop\FSDS-Class-Files\OpenCV\elephant.jpeg")
input
# Out:
# array([[[206, 152, 119],
#         [206, 152, 119],
#         [207, 153, 120],
#         ...,
#         [203, 149, 114],
#         [203, 149, 114],
#         [202, 148, 113]],
#
#        [[206, 152, 119],
#         [207, 153, 120],
#         [207, 153, 120],
#         ...,
#         [203, 149, 114],
#         [203, 149, 114],
#         [202, 148, 113]],
#
#        [[207, 153, 120],
#         [207, 153, 120],
#         [207, 153, 120],
#         ...,
#         [203, 149, 114],
#         [203, 149, 114],
#         [202, 148, 113]],
#
#        ...,
#
#        [[ 80, 146, 197],
#         [ 84, 150, 201],
#         [ 83, 149, 200],
#         ...,
#         [ 82, 143, 193],
#         [ 77, 138, 188],
#         [ 78, 139, 189]],
#
#        [[ 74, 140, 191],
#         [ 78, 144, 195],
#         [ 77, 143, 194],
#         ...,
#         [ 82, 143, 193],
#         [ 77, 138, 188],
#         [ 78, 139, 189]],
#
#        [[ 68, 134, 185],
#         [ 72, 138, 189],
#         [ 71, 137, 188],
# ...

# %%
cv2.imshow("Elephant", input)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
print('Height of image is : ', int(input.shape[0]), 'pixels')
print('Width of image is : ', int(input.shape[1]), 'pixels')
# Out:
# Height of image is :  187 pixels
# Width of image is :  270 pixels

# %%
cv2.imwrite(r"C:\Users\MUBASSHIR\OneDrive\Desktop\FSDS-Class-Files\OpenCV\output.png", input)
# Out:
# True
