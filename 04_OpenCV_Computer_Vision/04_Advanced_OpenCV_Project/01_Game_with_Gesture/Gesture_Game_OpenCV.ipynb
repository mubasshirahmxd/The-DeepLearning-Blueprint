# %% [markdown]
# <h2 style='text-align:center;'>🎮 Gesture Game Controller — MediaPipe + OpenCV</h2>

# %% [markdown]
# This notebook explains a **gesture-based controller** that detects index finger swipes using MediaPipe Hands and triggers arrow key presses using PyAutoGUI.

# %% [markdown]
# <h2 style='text-align:center;'>🧠 Theory</h2>
# We detect the index fingertip (landmark 8), calculate dx and dy between frames, and map them to gestures (L/R/U/D).

# %% [markdown]
# <h2 style='text-align:center;'>⚙️ Setup & Imports</h2>

# %%
import cv2, mediapipe as mp, pyautogui, time
print('✅ Imports successful! Run this locally for webcam + pyautogui support.')

# %% [markdown]
# <h2 style='text-align:center;'>💻 Run the Controller</h2>

# %%
# from handgame import run_hand_game
# run_hand_game(hud=True, trail=True)
print('👉 Uncomment above lines to run locally in VSCode.')

# %% [markdown]
# <h2 style='text-align:center;'>✅ Summary</h2>
# - Detects finger swipes using MediaPipe.
# - Controls keyboard games using PyAutoGUI.
# - Includes HUD overlay, FPS counter, and trail visualization.
