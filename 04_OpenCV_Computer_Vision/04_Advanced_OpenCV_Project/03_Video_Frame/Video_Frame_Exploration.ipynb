# %% [markdown]
# <h2 style='text-align:center;'>🎥 Video Frame Exploration — OpenCV</h2>
#
# This notebook demonstrates how a video is processed frame by frame using OpenCV.

# %% [markdown]
# <h2 style='text-align:center;'>🧠 Concept</h2>
#
# A video is a sequence of frames (images). OpenCV reads and displays them sequentially to create motion.

# %% [markdown]
# <h2 style='text-align:center;'>⚙️ Setup & Imports</h2>

# %%
import cv2, time, numpy as np
print('✅ Imports successful!')

# %% [markdown]
# <h2 style='text-align:center;'>📷 Step 1 — Display a Single Frame</h2>

# %%
# from video_frame_reader import show_single_frame
# show_single_frame()

# %% [markdown]
# <h2 style='text-align:center;'>⏩ Step 2 — Manual Frame Navigation</h2>

# %%
# from video_frame_reader import manual_frame_navigation
# manual_frame_navigation()

# %% [markdown]
# <h2 style='text-align:center;'>🎬 Step 3 — Continuous Playback with FPS</h2>

# %%
# from video_frame_reader import continuous_playback
# continuous_playback()

# %% [markdown]
# <h2 style='text-align:center;'>✅ Summary</h2>
#
# We explored three stages of video frame handling in OpenCV — single frame, manual frame-by-frame navigation, and continuous playback with FPS display.
