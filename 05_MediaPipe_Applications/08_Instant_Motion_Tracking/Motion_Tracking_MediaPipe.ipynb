# %% [markdown]
# <h2 style="text-align:center;">📡 Instant Motion Tracking — MediaPipe Hands</h2>
#
# This notebook demonstrates **real-time motion tracking** using **MediaPipe Hands**. We draw landmarks and a trajectory trail for the index fingertip to visualize motion paths.

# %% [markdown]
# <h2 style="text-align:center;">🧠 Concept</h2>
#
# We use MediaPipe Hands to get reliable hand landmarks each frame and draw a motion trail for landmark **#8 (index fingertip)**. This demonstrates motion analysis and can be extended to gesture recognition.

# %% [markdown]
# <h2 style="text-align:center;">⚙️ Setup & Imports</h2>

# %%
import cv2
import mediapipe as mp
import time
from collections import deque
import warnings
warnings.filterwarnings("ignore")

print("Libraries imported — ready to run webcam demo (VSCode/Notebook).")
# Out:
# Libraries imported — ready to run webcam demo (VSCode/Notebook).

# %% [markdown]
# <h2 style="text-align:center;">💻 Run Real-Time Motion Tracking (Webcam)</h2>
#
# The cell below runs the demo. Press **ESC** or **q** to quit. Press **c** to clear the trail. If running in a notebook that does not support webcam display (e.g., hosted Colab without local runtime), run `motion_tracking.py` locally in VSCode/terminal.

# %%
# Option 1: Call the script function (if motion_tracking.py is in the same folder)
# from motion_tracking import run_motion_tracking
# run_motion_tracking(trail_length=64, draw_trail=True)

print("To run the demo, either execute the script locally or uncomment the lines above.")

# %% [markdown]
# <h2 style="text-align:center;">📜 Sir's Original Code (Reference)</h2>
#
# Original reference used to create this module: `Instant Motion Tracking with MediaPipe.py` — refactored into a reusable script and notebook demo.

# %% [markdown]
# <h2 style="text-align:center;">✅ Summary & Next</h2>
#
# Module includes:
# - Reusable `motion_tracking.py` script
# - Interactive trajectory trail (press c to clear)
#
# Next: 09_Object_Detection (2D) — shall I proceed?
