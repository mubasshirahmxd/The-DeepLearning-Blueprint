# %% [markdown]
# <h2 style='text-align:center;'>🎭 Advanced 3D Face Transformations — MediaPipe</h2>
#
# This notebook walks through advanced 3D face techniques using MediaPipe Face Mesh and supporting modules. We progress from visualization to transformations, replacement, and pose-driven AR effects.

# %% [markdown]
# <h2 style='text-align:center;'>📍 Step 1 — Face Mesh Visualization</h2>
#
# Run the visualization script or the cell below to view the face mesh (mesh, contours, irises).

# %%
from face3d_visualization import face3d_visualization

# Uncomment to run the webcam visualization
face3d_visualization()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'

# %% [markdown]
# <h2 style='text-align:center;'>🧮 Step 2 — 3D Transformation (Matrix Scaling)</h2>
#
# This step applies a simple scaling matrix to the normalized 3D landmarks and draws the transformed landmarks alongside the original mesh.

# %%
from face3d_transform_matrix import face3d_transform_matrix

# Uncomment to run
# face3d_transform_matrix(scale=1.5)

# %% [markdown]
# <h2 style='text-align:center;'>🧑‍🎨 Step 3 — Face Replacement / Morphing</h2>
#
# Capture a replacement face by pressing 'c' in the webcam window, then the script overlays that face into the detected ROI.

# %%
from face3d_replacement import face3d_replacement

# Uncomment to run
# face3d_replacement()

# %% [markdown]
# <h2 style='text-align:center;'>🎨 Step 4 — Pose-driven AR Color Filter</h2>
#
# Uses Pose landmarks (wrists) to trigger or guide AR color effects on the frame.

# %%
from pose_color_ar import pose_color_ar

# Uncomment to run
# pose_color_ar()

# %% [markdown]
# <h2 style='text-align:center;'>📜 Sir's Reference Codes</h2>
#
# The original four scripts from your instructor have been refactored into clean, modular versions in this folder.

# %% [markdown]
# <h2 style='text-align:center;'>✅ Summary & Next Steps</h2>
#
# You can run each script standalone (VSCode) or call them from this notebook. Add media screenshots into the `media_assets/` folder for documentation and README screenshots.
