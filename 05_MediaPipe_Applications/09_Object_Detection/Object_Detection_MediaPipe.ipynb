# %% [markdown]
# <h2 style='text-align:center;'>📷 2D Object Detection — MediaPipe Face Detection</h2>
#
# This notebook demonstrates **real-time 2D face detection** using MediaPipe's Face Detection solution. It draws bounding boxes, shows confidence percentages, face count, and FPS. Works in VSCode and Colab (with local runtime).

# %% [markdown]
# <h2 style='text-align:center;'>🧠 Theory Overview</h2>
#
# MediaPipe Face Detection is a lightweight model optimized for real-time face detection. It returns detections with relative bounding boxes and confidence scores. Typical uses: face tracking, camera auto-focus, analytics.

# %% [markdown]
# <h2 style='text-align:center;'>⚙️ Setup & Imports</h2>

# %%
import cv2
import mediapipe as mp
import time

print('Libraries imported — ready for Face Detection demo.')

# %% [markdown]
# <h2 style='text-align:center;'>💻 Real-Time Face Detection (Webcam)</h2>
#
# Run the cell below to start webcam-based face detection. Press **ESC** or **q** to quit.

# %%
# Demo: Run the face detection function from the script
# from object_detection import run_face_detection
# run_face_detection(min_detection_confidence=0.5)

print('To run the demo, either execute the script locally or uncomment the lines above.')

# %% [markdown]
# <h2 style='text-align:center;'>📜 Sir's Reference Code</h2>
#
# Below is a condensed version of your instructor's original script for continuity and learning.

# %%
import cv2
import mediapipe as mp

mp_face_detection = mp.solutions.face_detection
mp_drawing = mp.solutions.drawing_utils

cap = cv2.VideoCapture(0)
with mp_face_detection.FaceDetection() as face_detection:
    while cap.isOpened():
        success, image = cap.read()
        if not success:
            break
        image = cv2.flip(image, 1)
        results = face_detection.process(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
        if results.detections:
            for detection in results.detections:
                mp_drawing.draw_detection(image, detection)
        cv2.imshow('Sir Face Detection', image)
        if cv2.waitKey(1) & 0xFF == 27:
            break
cap.release()
cv2.destroyAllWindows()

# %% [markdown]
# <h2 style='text-align:center;'>✅ Summary</h2>
#
# | Topic | Covered |
# |-------|---------|
# | Face Detection (2D) | ✅ |
# | Bounding Box + Confidence | ✅ |
# | Face Count + FPS Overlay | ✅ |
#
# Next: finalize README and push to GitHub, or add advanced multi-object detection.
